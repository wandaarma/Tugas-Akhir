# %%
# Import Library Python
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import os

# %%
clean_postings = pd.read_csv('clean_postings.csv')
clean_profiles = pd.read_csv('clean_profiles.csv')

# %%
# Count similarity score between job description and profile description using TF-IDF

vectorizer = TfidfVectorizer(min_df=10, max_df=0.8, sublinear_tf=True, use_idf=True)
job_vectors = vectorizer.fit_transform(clean_postings['combined'])
profile_vectors = vectorizer.transform(clean_profiles['combined'])

similarity_matrix = cosine_similarity(profile_vectors, job_vectors)

top_recommendations = []

for profile_idx in range(len(clean_profiles)):
    # Get the index of the job with the highest similarity score for this profile
    top_job_idx = np.argmax(similarity_matrix[profile_idx])
    top_similarity_score = similarity_matrix[profile_idx, top_job_idx]

    # Append the top recommendation details to the list
    top_recommendations.append({
        'profile_id': clean_profiles.iloc[profile_idx]['id'],
        'profile_position': clean_profiles.iloc[profile_idx]['position'],
        'job_title': clean_postings.iloc[top_job_idx]['title'],
        'description_similarity': top_similarity_score
    })

# Create a DataFrame from the list of top recommendations
recommendations_df = pd.DataFrame(top_recommendations)
recommendations_df = recommendations_df.sort_values(by='description_similarity', ascending=False)
recommendations_df
# Out:
#                              profile_id  \
# 251              mariateresa-e-6694b497
# 292          dr-hala-el-tawil-049289156
# 206              david-mcadams-9498a846
# 299  a-g%C3%B6khan-%C3%A7imen-2b0365100
# 349              syed-m-hassan-01066aa1
# ..                                  ...
# 170           ahmad-alshugairi-0322b241
# 164                         jonahmolina
# 278              loo-jia-liang-2134aa26
# 224       tony-van-de-kasteele-6150a933
# 440           austin-townsend-2405a6120
#
#                                       profile_position  \
# 251                     elementary school teacher miur
# 292  clinical pharmacist bsc pharmbcpscphq teamstep...
# 206  architecturesolution engineer project developm...
# 299                                    english teacher
# 349  intelligent automation team lead rpa developer...
# ..                                                 ...
# 170                       ceo aram alehsan holding ltd
# 164  certified level thermographer president infrar...
# 278           student nanyang technological university
# 224                       owner browniesdownies zwolle
# 440               director operations idrive logistics
#
#                                  job_title  description_similarity
# 251              elementary school teacher                0.677383
# 292                    clinical pharmacist                0.504882
# 206                  healthrules developer                0.504097
# 299                                teacher                0.494033
# 349  robotic process automation consultant                0.451779
# ..                                     ...                     ...
# 170                     multiple positions                0.115120
# 164        customer service representative                0.110605
# 278                   lead auditor banking                0.108357
# 224                 pt entrepreneur intern                0.106452
# 440             account director corporate                0.104167
#
# [497 rows x 4 columns]

# %%
recommendations_df = recommendations_df.dropna(subset=['profile_position', 'job_title'])
recommendations_df.isnull().sum()
# Out:
# profile_id                0
# profile_position          0
# job_title                 0
# description_similarity    0
# dtype: int64

# %%
# Count similarity score between job title and profile position to determine how good the model 

vectorizer1 = TfidfVectorizer(min_df=0, max_df=0.8, sublinear_tf=True, use_idf=True)
position_vectors = vectorizer.fit_transform(recommendations_df['profile_position'])
title_vectors = vectorizer.transform(recommendations_df['job_title'])

similarity_matrix1 = cosine_similarity(position_vectors, title_vectors)

recommendations_df['title_similarity'] = np.diagonal(similarity_matrix1)
recommendations1_df = recommendations_df.sort_values(by='description_similarity', ascending=False)
recommendations1_df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17548\1166149799.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recommendations_df['title_similarity'] = np.diagonal(similarity_matrix1)
#                              profile_id  \
# 251              mariateresa-e-6694b497
# 292          dr-hala-el-tawil-049289156
# 206              david-mcadams-9498a846
# 299  a-g%C3%B6khan-%C3%A7imen-2b0365100
# 349              syed-m-hassan-01066aa1
# ..                                  ...
# 170           ahmad-alshugairi-0322b241
# 164                         jonahmolina
# 278              loo-jia-liang-2134aa26
# 224       tony-van-de-kasteele-6150a933
# 440           austin-townsend-2405a6120
#
#                                       profile_position  \
# 251                     elementary school teacher miur
# 292  clinical pharmacist bsc pharmbcpscphq teamstep...
# 206  architecturesolution engineer project developm...
# 299                                    english teacher
# 349  intelligent automation team lead rpa developer...
# ..                                                 ...
# 170                       ceo aram alehsan holding ltd
# 164  certified level thermographer president infrar...
# 278           student nanyang technological university
# 224                       owner browniesdownies zwolle
# 440               director operations idrive logistics
#
#                                  job_title  description_similarity  \
# 251              elementary school teacher                0.677383
# 292                    clinical pharmacist                0.504882
# 206                  healthrules developer                0.504097
# 299                                teacher                0.494033
# 349  robotic process automation consultant                0.451779
# ..                                     ...                     ...
# 170                     multiple positions                0.115120
# 164        customer service representative                0.110605
# 278                   lead auditor banking                0.108357
# 224                 pt entrepreneur intern                0.106452
# 440             account director corporate                0.104167
#
#      title_similarity
# 251          0.000000
# 292          0.000000
# 206          0.438653
# 299          0.000000
# 349          0.000000
# ..                ...
# 170          0.000000
# 164          0.000000
# 278          0.000000
# 224          0.000000
# 440          0.653903
#
# [492 rows x 5 columns]

# %%
recommendations2_df = recommendations_df.sort_values(by='title_similarity', ascending=False)
recommendations2_df
# Out:
#                       profile_id  \
# 205     melissa-sninsky-13a6a08b
# 414       david-walker-1624a3198
# 93          lexi-smith-9607ba172
# 324  stefan-kalenderov-4ba886164
# 486   tim-anderson-mba-81a7ab163
# ..                           ...
# 386             donna-bianchi-06
# 492                nagylagouveia
# 367       bill-kingzett-42b09632
# 39     anthony-cordeiro-41857b6b
# 286       fadime-turgut-38772362
#
#                                       profile_position  \
# 205                         assistant property manager
# 414                student western illinois university
# 93                            experienced team manager
# 324  certified bc salesforce commerce cloud fullsta...
# 486  chief financial officer ready electric company...
# ..                                                 ...
# 386  administrative receptionist fresenius medical ...
# 492               marketing endomarketing social media
# 367                              business entrepreneur
# 39                 administration home healthsmith llc
# 286                         product manager lc waikiki
#
#                                              job_title  \
# 205                         assistant property manager
# 414  veterinary student representative western univ...
# 93                                front office manager
# 324                               salesforce developer
# 486  chief financial officer national retail growth...
# ..                                                 ...
# 386                            front desk receptionist
# 492                                      sap developer
# 367                             pt entrepreneur intern
# 39                    environmental operations manager
# 286                  sales associate south coast plaza
#
#      description_similarity  title_similarity
# 205                0.208958               1.0
# 414                0.163315               1.0
# 93                 0.239136               1.0
# 324                0.227415               1.0
# 486                0.227536               1.0
# ..                      ...               ...
# 386                0.228908               0.0
# 492                0.229408               0.0
# 367                0.229523               0.0
# 39                 0.229659               0.0
# 286                0.207087               0.0
#
# [492 rows x 5 columns]

# %%
# DCG
def dcg(scores_dcg, k):
    scores_dcg = np.array(scores_dcg[:k])
    return np.sum(scores_dcg / np.log2(np.arange(1, len(scores_dcg) + 1) + 1))
k = 100
dcg_score = dcg(recommendations1_df['title_similarity'], k)

print(f"DCG untuk {k} item teratas: {dcg_score}")
# Out:
# DCG untuk 100 item teratas: 2.295903477733675

# %%
# IDCG
def idcg(scores_idcg, k):
    scores_idcg = np.array(scores_idcg[:k])
    return np.sum(scores_idcg / np.log2(np.arange(1, len(scores_idcg) + 1) + 1))
k = 100
idcg_score = idcg(recommendations2_df['title_similarity'], k)

print(f"IDCG untuk {k} item teratas: {idcg_score}")
# Out:
# IDCG untuk 100 item teratas: 16.11654641460292

# %%
# NDCG
dcg_score/idcg_score
# Out:
# 0.1424562942128468
